# %% [markdown]
# ### Week 3: Introduction
# Welcome to this laboratory class focused on **DeePromoter** and the crucial role of **promoter regions** in gene regulation. Promoter regions are essential DNA sequences that control the initiation of transcription, influencing gene expression.
#
# The central prediction of this study is that **DeePromoter**, a robust deep learning model, can identify and classify short eukaryotic promoter sequences in both humans and mice. This model is designed to predict **TATA-type** promoters (those with the TATA box) as well as **non-TATA-type** promoters.
#
# In this session, we will focus on **DeePromoter** and investigate how it performs when trained on different datasets. We will explore its limitations and the interpretations of its results, providing a detailed understanding of its capabilities. By the end of this session, you will gain insights into how DeePromoter handles promoter prediction and the factors that influence its performance across various datasets.
#
# Sources
# 1. [Publication](https://www.frontiersin.org/journals/genetics/articles/10.3389/fgene.2019.00286/full)
# 2. [Implementation repository](https://github.com/egochao/DeePromoter/tree/main)

# %% [markdown]
# ### 2. DeePromoter
# The main idea behind the DeePromoter algorithm is to leverage advanced deep learning techniques to accurately predict eukaryotic promoter sequences from raw DNA sequences, specifically targeting both TATA and non-TATA promoters in human and mouse genomes. Here’s an overview of the core components and methodology:
#
# **1. Architecture**
#
# DeePromoter combines two distinct neural network architectures:
#
# - Convolutional Neural Network (CNN): This layer is responsible for automatically extracting features from the input sequences. The CNN consists of multiple convolutional layers that apply filters to the sequence data, capturing local patterns and motifs related to promoter sequences.
#
# - Bidirectional Long Short-Term Memory (BiLSTM): Following the CNN layers, BiLSTM is used to capture long-range dependencies between the nucleotide sequences. BiLSTM processes the sequence data in both forward and backward directions, enhancing the model's ability to understand contextual information.
#
# **2. Challenging Negative Set**
#
# Instead of using random (non-promoter) genomic  sequences as the negative dataset, DeePromoter adopts a more sophisticated approach by constructing a challenging negative set from the promoter sequences. This was done to improve the model's discrimination ability and reduce false positive predictions. The challenging aspect of the negative set pushes the algorithm to learn a deeper representation of the features that distinguish promoters from non-promoters.
# ![deepromoter.jpg](data:image/jpeg;base64,...)
#
# **3. Computation and Training**
#
# - The model processes sequences of a fixed length (300 bp), focusing on the region around transcription start sites.
#
# - The architecture includes multiple convolutional layers with varying window sizes, allowing it to capture different types of sequence features.
#
# - Dropout layers are utilized to prevent overfitting and improve generalization.
#
# **4. Evaluation and Results**
#
# The DeePromoter model is trained on a curated dataset that includes both TATA and non-TATA promoters. The evaluation phase compares its performance against existing tools such as CNNProm, demonstrating superior results in terms of precision, recall, and Matthews correlation coefficient (MCC) metrics across the different datasets.
#
# **5. Impact**
#
# The algorithm's ability to accurately differentiate between promoter and non-promoter sequences offers significant improvements in the field of bioinformatics, particularly in the study of gene regulation. By effectively reducing false positives while maintaining high sensitivity, DeePromoter positions itself as a valuable tool for researchers in genomics and related fields.
#
# In summary, the main idea behind DeePromoter is to utilize a combination of CNN and LSTM architecture, improved dataset preparation, and deep learning techniques to enhance the accuracy and reliability of promoter sequence prediction.

# %% [markdown]
# ### 3. Let's test it

# %% [markdown]
# ##### 3.1 Clone the repo to your working directory
# Remember: The working directory in colab automatically deletes after working. If you want to save your results- add repo to your google drive.

# %%
# !git clone https://github.com/egochao/DeePromoter.git
# Out:
# Cloning into 'DeePromoter'...

# %%
# %cd DeePromoter
# Out:
# c:\Users\nelia\OneDrive\Рабочий стол\semester 2\DeepLife\03\deep4life_files\DeePromoter
# c:\Users\nelia\OneDrive\Рабочий стол\semester 2\DeepLife\.venv_deeplife\Lib\site-packages\IPython\core\magics\osm.py:417: UserWarning: This is now an optional IPython functionality, setting dhist requires you to install the `pickleshare` library.
#   self.shell.db['dhist'] = compress_dhist(dhist)[-100:]

# %% [markdown]
# ##### 3.2 Install dependencies

# %%
#!pip install -r requirements.txt
# !pip install icecream
# Out:
# Collecting icecream
#   Downloading icecream-2.1.4-py3-none-any.whl.metadata (1.3 kB)
# Requirement already satisfied: colorama>=0.3.9 in c:\users\nelia\onedrive\рабочий стол\semester 2\deeplife\.venv_deeplife\lib\site-packages (from icecream) (0.4.6)
# Requirement already satisfied: pygments>=2.2.0 in c:\users\nelia\onedrive\рабочий стол\semester 2\deeplife\.venv_deeplife\lib\site-packages (from icecream) (2.19.1)
# Requirement already satisfied: executing>=2.1.0 in c:\users\nelia\onedrive\рабочий стол\semester 2\deeplife\.venv_deeplife\lib\site-packages (from icecream) (2.2.0)
# Requirement already satisfied: asttokens>=2.0.1 in c:\users\nelia\onedrive\рабочий стол\semester 2\deeplife\.venv_deeplife\lib\site-packages (from icecream) (3.0.0)
# Downloading icecream-2.1.4-py3-none-any.whl (14 kB)
# Installing collected packages: icecream
# Successfully installed icecream-2.1.4
# [notice] A new release of pip is available: 24.2 -> 25.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %% [markdown]
# ##### 3.3 Training and/or loading DeePromoter model

# %%
import torch
import math
import argparse
import torch.optim as optim
from torch import nn
from icecream import ic
from pathlib import Path

from modules.deepromoter import DeePromoter
from dataloader import load_data_test, load_data
from test_1 import evaluate, mcc
import matplotlib.pyplot as plt


device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

def train(data_path, pretrain=None, exp_name="test", training=True, ker=None, epoch_num=1000):
    """
    Training
    :param data_path: Path to the txt data file
    :param pretrain: Path to weight for continue training
    :param exp_name: Folder name to save the results
    :param training: If False, performs testing only
    :param ker: List kernel size of list CNN applying to the protein sequence
    :param epoch_num: Max epoch to train
    """
    if ker is None:
        ker = [27, 14, 7]

    # create the experiment folder to save the result
    output = Path("./output")
    output.mkdir(exist_ok=True)
    exp_folder = output.joinpath(exp_name)
    exp_folder.mkdir(exist_ok=True)

    # load data
    ic("Data loading")
    data = load_data(data_path, device=device)
    train_pos, val_pos, test_pos, train_neg, val_neg, test_neg = data

    # model define
    net = DeePromoter(ker)
    net.to(device)

    # load pre-train model
    if pretrain is not None:
        net.load_state_dict(torch.load(pretrain))

    # define loss, optimizer
    criterion = nn.CrossEntropyLoss()
    # optimizer = optim.SGD(net.parameters(), lr=0.001, momentum=0.9)
    optimizer = optim.Adam(net.parameters(), lr=0.00001)
    mcc_scores, precision_scores, recall_scores = [], [], []
    running_loss = 0
    best_mcc = 0
    best_precision = 0
    best_recall = 0
    break_after = 10
    last_update_best = 0
    pbar = range(epoch_num)
    ic("Start training")
    if training:
        print(f"train_pos type: {type(train_pos)}, train_neg type: {type(train_neg)}")

        for epoch in pbar:
            for i, (batch_pos, batch_neg) in enumerate(zip(train_pos, train_neg)):
                inputs = torch.cat((batch_pos[0], batch_neg[0]), dim=0)
                labels = torch.cat((batch_pos[1], batch_neg[1]), dim=0)

                # zero the parameter gradients
                optimizer.zero_grad()

                # pass model to
                outputs = net(inputs)
                loss = criterion(outputs, labels.long())
                loss.backward()
                optimizer.step()

                running_loss += loss.item()


            if epoch % 10 == 0:
                torch.save(net.state_dict(), str(exp_folder.joinpath("epoch_" + str(epoch) + ".pth")))
                net.eval()
                eval_data, _ = evaluate(net, [val_pos, val_neg])
                precision, recall, MCC = mcc(eval_data)
                mcc_scores.append(MCC)
                precision_scores.append(precision)
                recall_scores.append(recall)
                net.train()
                ic("Epoch :", epoch, "Experiment :", exp_name)
                ic("precision :", precision)
                ic("recall :", recall)
                ic("MCC :", MCC)

                # save best model
                if precision > best_precision:
                    best_precision = precision
                    ic("Update best precision")
                    torch.save(net.state_dict(), str(exp_folder.joinpath("best_precision.pth")))
                if recall > best_recall:
                    best_recall = recall
                    ic("Update best recall")
                    torch.save(net.state_dict(), str(exp_folder.joinpath("best_recall.pth")))
                if MCC > best_mcc:
                    ic("Update best MCC")
                    best_mcc = MCC
                    torch.save(net.state_dict(), str(exp_folder.joinpath("best_mcc.pth")))
                    last_update_best = 0
                else:
                    last_update_best += 1
                if last_update_best >= break_after:
                    break
            if last_update_best >= break_after:
                break

    return mcc_scores, precision_scores, recall_scores

# %%
# #you can train the model yourself (uncomment the section to do so) but it takes approx 1hour on gpu
# data_path_human_noTATA = "C:/Users/nelia/OneDrive/Рабочий стол/semester 2/DeepLife/03/deep4life_files/DeePromoter/data/human/nonTATA/hs_pos_nonTATA.txt"
# mcc_scores_no, precision_scores_no, recall_scores_no = train(data_path_human_noTATA, pretrain=None, exp_name="train_human_noTATA", training=True, ker=None, epoch_num=400)
# Out:
# ic| 'Data loading'
# Key error :  N 200
# Key error :  N 200
# ic| 'Start training'
# train_pos type: <class 'torch.utils.data.dataloader.DataLoader'>, train_neg type: <class 'torch.utils.data.dataloader.DataLoader'>
# ic| "Epoch :": 'Epoch :'
#     epoch: 0
#     "Experiment :": 'Experiment :'
#     exp_name: 'train_human_noTATA'
# ic| 'precision :', precision: 0.6346433770014556
# ic| 'recall :', recall: 0.6730991895021228
# ic| 'MCC :', MCC: 0.2861297850407949
# ic| 'Update best precision'
# ic| 'Update best recall'
# ic| 'Update best MCC'
# ic| "Epoch :": 'Epoch :'
#     epoch: 10
#     "Experiment :": 'Experiment :'
#     exp_name: 'train_human_noTATA'
# ic| 'precision :', precision: 0.7934828607702074
# ic| 'recall :', recall: 0.7236588189888075
# ic| 'MCC :', MCC: 0.5373992578323399
# ic| 'Update best precision'
# ic| 'Update best recall'
# ic| 'Update best MCC'
# ic| "Epoch :": 'Epoch :'
#     epoch: 20
#     "Experiment :": 'Experiment :'
#     exp_name: 'train_human_noTATA'
# ic| 'precision :', precision: 0.7857432158768732
# ic| 'recall :', recall: 0.748745658047086
# ic| 'MCC :', MCC: 0.5451820795762581
# ic| 'Update best recall'
# ic| 'Update best MCC'
# ic| "Epoch :": 'Epoch :'
#     epoch: 30
#     "Experiment :": 'Experiment :'
#     exp_name: 'train_human_noTATA'
# ic| 'precision :', precision: 0.8008957654723127
# ic| 'recall :', recall: 0.7591663450405249
# ic| 'MCC :', MCC: 0.5712120060094165
# ic| 'Update best precision'
# ic| 'Update best recall'
# ic| 'Update best MCC'
# ic| "Epoch :": 'Epoch :'
#     epoch: 40
#     "Experiment :": 'Experiment :'
#     exp_name: 'train_human_noTATA'
# ic| 'precision :', precision: 0.813810110974106
# ic| 'recall :', recall: 0.7641837128521807
# ic| 'MCC :', MCC: 0.5904465817053662
# ic| 'Update best precision'
# ic| 'Update best recall'
# ic| 'Update best MCC'
# ic| "Epoch :": 'Epoch :'
#     epoch: 50
#     "Experiment :": 'Experiment :'
#     exp_name: 'train_human_noTATA'
# ic| 'precision :', precision: 0.7916986933128363
# ic| 'recall :', recall: 0.7950598224623697
# ic| 'MCC :', MCC: 0.5858794598151095
# ic| 'Update best recall'
# ic| "Epoch :": 'Epoch :'
#     epoch: 60
#     "Experiment :": 'Experiment :'
#     exp_name: 'train_human_noTATA'
# ic| 'precision :', precision: 0.8080924855491329
# ic| 'recall :', recall: 0.8093400231570822
# ic| 'MCC :', MCC: 0.6171369762562824
# ic| 'Update best recall'
# ic| 'Update best MCC'
# ic| "Epoch :": 'Epoch :'
#     epoch: 70
#     "Experiment :": 'Experiment :'
#     exp_name: 'train_human_noTATA'
# ic| 'precision :', precision: 0.7994132746607994
# ic| 'recall :', recall: 0.8413739868776534
# ic| 'MCC :', MCC: 0.631128609563406
# ic| 'Update best recall'
# ic| 'Update best MCC'
# ic| "Epoch :": 'Epoch :'
#     epoch: 80
#     "Experiment :": 'Experiment :'
#     exp_name: 'train_human_noTATA'
# ic| 'precision :', precision: 0.7903225806451613
# ic| 'recall :', recall: 0.8888460054033192
# ic| 'MCC :', MCC: 0.658163903220394
# ic| 'Update best recall'
# ic| 'Update best MCC'
# ic| "Epoch :": 'Epoch :'
#     epoch: 90
#     "Experiment :": 'Experiment :'
#     exp_name: 'train_human_noTATA'
# ic| 'precision :', precision: 0.8043844856661045
# ic| 'recall :', recall: 0.920494017753763
# ic| 'MCC :', MCC: 0.7040151594423871
# ic| 'Update best recall'
# ic| 'Update best MCC'
# ic| "Epoch :": 'Epoch :'
#     epoch: 100
#     "Experiment :": 'Experiment :'
#     exp_name: 'train_human_noTATA'
# ic| 'precision :', precision: 0.7798483891345547
# ic| 'recall :', recall: 0.9529139328444616
# ic| 'MCC :', MCC: 0.7013955374443553
# ic| 'Update best recall'
# ic| "Epoch :": 'Epoch :'
#     epoch: 110
#     "Experiment :": 'Experiment :'
#     exp_name: 'train_human_noTATA'
# ic| 'precision :', precision: 0.7985170857511283
# ic| 'recall :', recall: 0.9560015438054805
# ic| 'MCC :', MCC: 0.7291022158548891
# ic| 'Update best recall'
# ic| 'Update best MCC'
# ic| "Epoch :": 'Epoch :'
#     epoch: 120
#     "Experiment :": 'Experiment :'
#     exp_name: 'train_human_noTATA'
# ic| 'precision :', precision: 0.8370824812542604
# ic| 'recall :', recall: 0.9478965650328058
# ic| 'MCC :', MCC: 0.7701903609501154
# ic| 'Update best precision'
# ic| 'Update best MCC'
# ic| "Epoch :": 'Epoch :'
#     epoch: 130
#     "Experiment :": 'Experiment :'
#     exp_name: 'train_human_noTATA'
# ic| 'precision :', precision: 0.8080284881838783
# ic| 'recall :', recall: 0.9633346198379005
# ic| 'MCC :', MCC: 0.7484197162560355
# ic| 'Update best recall'
# ic| "Epoch :": 'Epoch :'
#     epoch: 140
#     "Experiment :": 'Experiment :'
#     exp_name: 'train_human_noTATA'
# ic| 'precision :', precision: 0.8554175293305728
# ic| 'recall :', recall: 0.9567734465457353
# ic| 'MCC :', MCC: 0.8007002793313791
# ic| 'Update best precision'
# ic| 'Update best MCC'
# ic| "Epoch :": 'Epoch :'
#     epoch: 150
#     "Experiment :": 'Experiment :'
#     exp_name: 'train_human_noTATA'
# ic| 'precision :', precision: 0.8157208088714938
# ic| 'recall :', recall: 0.9652643766885373
# ic| 'MCC :', MCC: 0.7600837469871579
# ic| 'Update best recall'
# ic| "Epoch :": 'Epoch :'
#     epoch: 160
#     "Experiment :": 'Experiment :'
#     exp_name: 'train_human_noTATA'
# ic| 'precision :', precision: 0.8686797752808989
# ic| 'recall :', recall: 0.9548436896950984
# ic| 'MCC :', MCC: 0.8145146057143028
# ic| 'Update best precision'
# ic| 'Update best MCC'
# ic| "Epoch :": 'Epoch :'
#     epoch: 170
#     "Experiment :": 'Experiment :'
#     exp_name: 'train_human_noTATA'
# ic| 'precision :', precision: 0.874029640084686
# ic| 'recall :', recall: 0.9560015438054805
# ic| 'MCC :', MCC: 0.8218392744313815
# ic| 'Update best precision'
# ic| 'Update best MCC'
# ic| "Epoch :": 'Epoch :'
#     epoch: 180
#     "Experiment :": 'Experiment :'
#     exp_name: 'train_human_noTATA'
# ic| 'precision :', precision: 0.8435810810810811
# ic| 'recall :', recall: 0.9637205712080278
# ic| 'MCC :', MCC: 0.7931093425688251
# ic| "Epoch :": 'Epoch :'
#     epoch: 190
#     "Experiment :": 'Experiment :'
#     exp_name: 'train_human_noTATA'
# ic| 'precision :', precision: 0.8740323715693173
# ic| 'recall :', recall: 0.958703203396372
# ic| 'MCC :', MCC: 0.8244100827731868
# ic| 'Update best precision'
# ic| 'Update best MCC'
# ic| "Epoch :": 'Epoch :'
#     epoch: 200
#     "Experiment :": 'Experiment :'
#     exp_name: 'train_human_noTATA'
# ic| 'precision :', precision: 0.8888888888888888
# ic| 'recall :', recall: 0.9540717869548437
# ic| 'MCC :', MCC: 0.8370664681546165
# ic| 'Update best precision'
# ic| 'Update best MCC'
# ic| "Epoch :": 'Epoch :'
#     epoch: 210
#     "Experiment :": 'Experiment :'
#     exp_name: 'train_human_noTATA'
# ic| 'precision :', precision: 0.8986141502552881
# ic| 'recall :', recall: 0.9509841759938248
# ic| 'MCC :', MCC: 0.8451261097369229
# ic| 'Update best precision'
# ic| 'Update best MCC'
# ic| "Epoch :": 'Epoch :'
#     epoch: 220
#     "Experiment :": 'Experiment :'
#     exp_name: 'train_human_noTATA'
# ic| 'precision :', precision: 0.8818310858765082
# ic| 'recall :', recall: 0.9590891547664995
# ic| 'MCC :', MCC: 0.8337734016412802
# ic| "Epoch :": 'Epoch :'
#     epoch: 230
#     "Experiment :": 'Experiment :'
#     exp_name: 'train_human_noTATA'
# ic| 'precision :', precision: 0.9021897810218978
# ic| 'recall :', recall: 0.9540717869548437
# ic| 'MCC :', MCC: 0.8520468573686135
# ic| 'Update best precision'
# ic| 'Update best MCC'
# ic| "Epoch :": 'Epoch :'
#     epoch: 240
#     "Experiment :": 'Experiment :'
#     exp_name: 'train_human_noTATA'
# ic| 'precision :', precision: 0.8947939262472885
# ic| 'recall :', recall: 0.9552296410652258
# ic| 'MCC :', MCC: 0.844847029006195
# ic| "Epoch :": 'Epoch :'
#     epoch: 250
#     "Experiment :": 'Experiment :'
#     exp_name: 'train_human_noTATA'
# ic| 'precision :', precision: 0.9135115070527097
# ic| 'recall :', recall: 0.9498263218834427
# ic| 'MCC :', MCC: 0.8605799088477545
# ic| 'Update best precision'
# ic| 'Update best MCC'
# ic| "Epoch :": 'Epoch :'
#     epoch: 260
#     "Experiment :": 'Experiment :'
#     exp_name: 'train_human_noTATA'
# ic| 'precision :', precision: 0.8860714285714286
# ic| 'recall :', recall: 0.95754534928599
# ic| 'MCC :', MCC: 0.8371548456386945
# ic| "Epoch :": 'Epoch :'
#     epoch: 270
#     "Experiment :": 'Experiment :'
#     exp_name: 'train_human_noTATA'
# ic| 'precision :', precision: 0.9061810154525386
# ic| 'recall :', recall: 0.9505982246236974
# ic| 'MCC :', MCC: 0.853206177275407
# ic| "Epoch :": 'Epoch :'
#     epoch: 280
#     "Experiment :": 'Experiment :'
#     exp_name: 'train_human_noTATA'
# ic| 'precision :', precision: 0.9078801331853497
# ic| 'recall :', recall: 0.9471246622925511
# ic| 'MCC :', MCC: 0.8518189699830533
# ic| "Epoch :": 'Epoch :'
#     epoch: 290
#     "Experiment :": 'Experiment :'
#     exp_name: 'train_human_noTATA'
# ic| 'precision :', precision: 0.9094955489614244
# ic| 'recall :', recall: 0.9463527595522964
# ic| 'MCC :', MCC: 0.8528812423788139
# ic| "Epoch :": 'Epoch :'
#     epoch: 300
#     "Experiment :": 'Experiment :'
#     exp_name: 'train_human_noTATA'
# ic| 'precision :', precision: 0.9307839388145316
# ic| 'recall :', recall: 0.9394056348900038
# ic| 'MCC :', MCC: 0.8695857429573051
# ic| 'Update best precision'
# ic| 'Update best MCC'
# ic| "Epoch :": 'Epoch :'
#     epoch: 310
#     "Experiment :": 'Experiment :'
#     exp_name: 'train_human_noTATA'
# ic| 'precision :', precision: 0.9062730627306274
# ic| 'recall :', recall: 0.9478965650328058
# ic| 'MCC :', MCC: 0.8507626904415136
# ic| "Epoch :": 'Epoch :'
#     epoch: 320
#     "Experiment :": 'Experiment :'
#     exp_name: 'train_human_noTATA'
# ic| 'precision :', precision: 0.9244781783681214
# ic| 'recall :', recall: 0.9401775376302586
# ic| 'MCC :', MCC: 0.8634977332360967
# ic| "Epoch :": 'Epoch :'
#     epoch: 330
#     "Experiment :": 'Experiment :'
#     exp_name: 'train_human_noTATA'
# ic| 'precision :', precision: 0.9149253731343283
# ic| 'recall :', recall: 0.9463527595522964
# ic| 'MCC :', MCC: 0.8588626827347673
# ic| "Epoch :": 'Epoch :'
#     epoch: 340
#     "Experiment :": 'Experiment :'
#     exp_name: 'train_human_noTATA'
# ic| 'precision :', precision: 0.912267657992565
# ic| 'recall :', recall: 0.9471246622925511
# ic| 'MCC :', MCC: 0.8566657084167278
# ic| "Epoch :": 'Epoch :'
#     epoch: 350
#     "Experiment :": 'Experiment :'
#     exp_name: 'train_human_noTATA'
# ic| 'precision :', precision: 0.9320610687022901
# ic| 'recall :', recall: 0.9424932458510228
# ic| 'MCC :', MCC: 0.8738486389682631
# ic| 'Update best precision'
# ic| 'Update best MCC'
# ic| "Epoch :": 'Epoch :'
#     epoch: 360
#     "Experiment :": 'Experiment :'
#     exp_name: 'train_human_noTATA'
# ic| 'precision :', precision: 0.9300646142151273
# ic| 'recall :', recall: 0.9444230027016596
# ic| 'MCC :', MCC: 0.8735120504091416
# ic| "Epoch :": 'Epoch :'
#     epoch: 370
#     "Experiment :": 'Experiment :'
#     exp_name: 'train_human_noTATA'
# ic| 'precision :', precision: 0.9240362811791383
# ic| 'recall :', recall: 0.9436510999614048
# ic| 'MCC :', MCC: 0.866270066917661
# ic| "Epoch :": 'Epoch :'
#     epoch: 380
#     "Experiment :": 'Experiment :'
#     exp_name: 'train_human_noTATA'
# ic| 'precision :', precision: 0.925226586102719
# ic| 'recall :', recall: 0.9455808568120417
# ic| 'MCC :', MCC: 0.8693728844611187
# ic| "Epoch :": 'Epoch :'
#     epoch: 390
#     "Experiment :": 'Experiment :'
#     exp_name: 'train_human_noTATA'
# ic| 'precision :', precision: 0.9311400153022188
# ic| 'recall :', recall: 0.9394056348900038
# ic| 'MCC :', MCC: 0.8699686652838147

# %% [markdown]
# ##### 3.4 Check the performance

# %%
plt.plot(mcc_scores_no, label='mcc')
plt.plot(precision_scores_no, label='precision')
plt.plot(recall_scores_no, label='recall')
plt.title('noTATA dataset')
plt.legend()
plt.xlabel('checkpoint')
plt.ylabel('score')
plt.show()

# %% [markdown]
# The plot above shows the metrics reflecting the model's learning progress. Now, let's examine how it classifies test examples.

# %%
#we will load already trained model here
path_noTATA_pretrained_model = "C:/Users/nelia/OneDrive/Рабочий стол/semester 2/DeepLife/03/deep4life_files/data/models/model_noTATA.pth"

# %%
import torch
from sklearn.metrics import confusion_matrix
import numpy as np
import matplotlib.pyplot as plt

def plot_confusion_matrix(cm, ax=None):
    """
    Plot the confusion matrix using matplotlib without labels and seaborn.
    :param cm: confusion matrix
    :param ax: axis to plot on, if None a new plot will be created
    """
    if ax is None:
        fig, ax = plt.subplots(figsize=(8, 6))

    # Plot the confusion matrix
    cax = ax.matshow(cm, cmap='Blues')
    fig.colorbar(cax)

    # Annotate the confusion matrix cells with the counts
    for (i, j), val in np.ndenumerate(cm):
        ax.text(j, i, str(val), ha='center', va='center', color='black', fontsize=14)

    ax.set_xlabel('Predicted Labels', fontsize=14)
    ax.set_ylabel('True Labels', fontsize=14)
    ax.set_title('Confusion Matrix', fontsize=16)
    plt.xticks(rotation=45)
    plt.yticks(rotation=45)
    plt.show()

def evaluate(net, loaders):
    """
    Infer and check results against labels
    :param net: Model object in eval state
    :param loaders: List of torch dataloader for infer
    :return: List of [correct, total] for every dataloader, list of predicted results in int type, list of confusion matrices
    """
    eval_result = list()
    ltotal = list()
    lcorrect = list()
    pred_result = list()
    true_result = list()  # To store the true labels for further analysis

    for load in loaders:
        total = 0
        correct = 0
        pred_list = list()
        true_list = list()  # To store true labels for confusion matrix

        for data in load:
            inputs = data[0]
            labels = data[1]
            outputs = net(inputs)
            _, predicted = torch.max(outputs.data, 1)

            total += labels.size(0)
            correct += (predicted == labels).sum().item()
            pred_list += list(predicted.cpu().numpy())
            true_list += list(labels.cpu().numpy())


        acc = correct / total
        eval_result.append(acc)
        lcorrect.append(correct)
        ltotal.append(total)
        pred_result.append(pred_list)
        true_result.append(true_list)

        # Compute confusion matrix for this dataloader
        cm = confusion_matrix(true_list, pred_list)


    return (lcorrect, ltotal), pred_result, cm

# %% [markdown]
# First, we'll use the function suggested by the authors of the repository. For testing the model, they input only promoters (without modifications, i.e., the negative dataset) and then check how many of these were classified as positive examples of promoters.

# %%
def test(data_path, pretrain,device,ker=None):
    if ker is None:
        ker = [27, 14, 7]

    dataloader = load_data_test(data_path=data_path, batch_size=32, device=device, num_cpu=10)

    # model define
    net = DeePromoter(ker)
    net.to(device)

    net.load_state_dict(torch.load(pretrain,map_location=torch.device(device)))


    net.eval()
    eval_data, results, confusion_matrice = evaluate(net, [dataloader])

    return eval_data, results, confusion_matrice

# %%
eval_data, results, confusion_matrice = test("C:/Users/nelia/OneDrive/Рабочий стол/semester 2/DeepLife/03/deep4life_files/DeePromoter/data/human/nonTATA/hs_pos_nonTATA.txt", 
                                             pretrain=path_noTATA_pretrained_model, device=device, ker=None)
# Out:
# Key error :  N 200
# c:\Users\nelia\OneDrive\Рабочий стол\semester 2\DeepLife\.venv_deeplife\Lib\site-packages\torch\nn\modules\conv.py:370: UserWarning: Using padding='same' with even kernel lengths and odd dilation may require a zero-padded copy of the input be created (Triggered internally at C:\actions-runner\_work\pytorch\pytorch\pytorch\aten\src\ATen\native\Convolution.cpp:1037.)
#   return F.conv1d(

# %%
positives = 0
all = 0
for example in results[0]:
  positives += example
  all += 1
print(f'Out of {all} promoters model predicted {positives} postitive promoters which is {round((positives/all),2)*100}%')
# Out:
# Out of 25920 promoters model predicted 24343 postitive promoters which is 94.0%

# %% [markdown]
# Now, let's modify the function provided by the authors to evaluate the model's performance in a more standard machine learning approach, using a test dataset with positive and negative examples separated during the data preparation process.

# %%
from torch.utils.data import DataLoader, ConcatDataset

def test_new(data_path, pretrain, ker=None):
    if ker is None:
        ker = [27, 14, 7]

    dataloader = load_data(data_path, device=device)
    # Assuming `positive_dataloader` and `negative_dataloader` are already defined in the repository files
    positive_dataloader = dataloader[2]  # Your DataLoader for positive examples
    negative_dataloader = dataloader[5]  # Your DataLoader for negative examples

    # Extract datasets from each DataLoader
    positive_dataset = positive_dataloader.dataset
    negative_dataset = negative_dataloader.dataset

    # Combine the datasets
    combined_dataset = ConcatDataset([positive_dataset, negative_dataset])

    # Create a new DataLoader from the combined dataset
    combined_dataloader = DataLoader(combined_dataset, batch_size=32, shuffle=True)

    # model define
    net = DeePromoter(ker)
    net.to(device)

    net.load_state_dict(torch.load(pretrain,map_location=torch.device(device)))

    net.eval()
    eval_data, results, confusion_matrice = evaluate(net, [combined_dataloader])

    return eval_data, results, confusion_matrice

# %%
eval_data_noTATA, results_noTATA , confusion_matrice_noTATA = test_new('/content/DeePromoter/data/human/nonTATA/hs_pos_nonTATA.txt',path_noTATA_pretrained_model )
plot_confusion_matrix(confusion_matrice_noTATA)
# Out:
# Key error :  N 200
# Key error :  N 200
# <ipython-input-12-1c0437e32f13>:27: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   net.load_state_dict(torch.load(pretrain,map_location=torch.device(device)))

# %%
accuracy_noTATA = eval_data_noTATA[0][0]/eval_data_noTATA[1][0]
print(f'The accuracy of the DeePromoter basedthe nonTATA dataset is {round(accuracy_noTATA,2)*100}%')
# Out:
# The accuracy of the DeePromoter basedthe nonTATA dataset is 95.0%

# %% [markdown]
# Great, we've demonstrated that DeePromoter performs well on the provided dataset, which consists solely of promoters with random modifications as the negative examples. But does this prove that it generalizes effectively? What will happen if we input completely random sequences from the human genome? Let's test it. We'll use a ready-made file for now, but if anyone is interested in how to obtain the file, they can check the script I’ve included (get_sequences.py). It uses Biopython to download the sequences from Ensembl.

# %% [markdown]
# ##### 3.5 Testing the model on random sequences from human genome

# %%
path_random_sequences = "C:/Users/nelia/OneDrive/Рабочий стол/semester 2/DeepLife/03/deep4life_files/data/sequences/random_sequences_25920.txt"

# %%
eval_data_random_noTATA, results_random_noTATA, confusion_matrice_random_noTATA = test(path_random_sequences, pretrain=path_noTATA_pretrained_model,device=device ,ker=None)
# Out:
# /usr/local/lib/python3.11/dist-packages/torch/utils/data/dataloader.py:617: UserWarning: This DataLoader will create 10 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(
# <ipython-input-9-bbacde621b56>:11: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   net.load_state_dict(torch.load(pretrain,map_location=torch.device(device)))

# %%
positives = 0
all = 0
for example in results_random_noTATA[0]:
  positives += example
  all += 1
print(f'Out of {all} promoters model predicted {positives} postitive promoters which is {round((positives/all),2)*100}%')
# Out:
# Out of 4945 promoters model predicted 4434 postitive promoters which is 90.0%

# %% [markdown]
# Here, we have completely random genomic sequences, and the model predicted most of them as promoters, similar to what happened when we used the dataset consisting only of promoters. Now, let's see what happens when we cut the random sequences and mix some parts of them, as done in the negative dataset preparation for the original paper.

# %%
eval_data_random_noTATA, results_random_noTATA, confusion_matrice_random_noTATA = test_new(path_random_sequences, pretrain=path_noTATA_pretrained_model, ker=None)
plot_confusion_matrix(confusion_matrice_random_noTATA)
# Out:
# <ipython-input-12-1c0437e32f13>:27: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   net.load_state_dict(torch.load(pretrain,map_location=torch.device(device)))

# %%
accuracy_noTATA_model = eval_data_random_noTATA[0][0]/eval_data_random_noTATA[1][0]
print(f'The accuracy of the DeePromoter for random sequences is {round(accuracy_noTATA_model,2)*100}%')
# Out:
# The accuracy of the DeePromoter for random sequences is 94.0%

# %% [markdown]
# **Question** What you can say about the result? Do you think this model is well suited to help find promoters regions?
#
# - the model is not so great for real-world data, sequences in the genome are not random, as in training dataset of DeePromoter, there are some specific sequences or different content of GC (less/more than 50% in different regions) and so on. Therefore, the model is not complete, as it relies on randomness of non-promoter regions (but they are not!)
# - this model is not interpretable...

# %% [markdown]
# ##### 3.6 Conclusion
# The model trained on a dataset consisting only of promoters and a negative set created from modified promoters performs well when focusing solely on machine learning metrics and results. However, this highlights the importance of understanding the data we’re working with. DeePromoter, trained only on promoters (with negative examples derived from positive ones), produces the same results for completely random sequences from human genome.

# %% [markdown]
# ###4. Random sequences vs promoters
#
# Now, let's adjust the original functions to utilize the model for distinguishing between real promoters and random sequences from the human genome. Files containing both promoters and random sequences are included in /data/sequences/ .

# %%
path_promotors = 'C:/Users/nelia/OneDrive/Рабочий стол/semester 2/DeepLife/03/deep4life_files/data/sequences/promoters.txt'
path_random_nopromotors = "C:/Users/nelia/OneDrive/Рабочий стол/semester 2/DeepLife/03/deep4life_files/data/sequences/random_sequences_nopromoters.txt"

# %%
from dataloader import LoadOnehot
from torch.utils.data import Dataset, DataLoader, random_split, ConcatDataset

def load_data_new(data_path_promotors,data_path_random ,train_potion=0.8, batch_size=32, num_cpu=0, 
                  device="cuda" if torch.cuda.is_available() else "cpu"):
    """
    Load all data
    :param data_path: Path to txt file contain promoter (1 DNA promoter on 1 line)
    :param train_potion: The potion of dataset spend for training
    :param rand_neg: Add random of DNA to negative datset
    :param batch_size: Batch size for loader
    :param num_cpu: Number of CPU perform load data in prallel
    :param device: Device to load data on
    :return: List of train, val, test dataset for positive and negative datset
    """
    # get dataset
    manual_seed = torch.Generator().manual_seed(42)
    pos_data = LoadOnehot(data_path_promotors, device=device)

    #YOUR CODE HERE
    #Tip: examine LoadOnehot class in dataloader file
    #neq_data = YOUR CODE HERE
    neg_data = LoadOnehot(data_path_random, device=device, is_pos=False)

    # calculate the size of train and test dataset
    train_num = int(len(pos_data)*train_potion)
    val_num = int(len(pos_data)*(1-train_potion)*0.5)
    split_size = [train_num, val_num, len(pos_data) - train_num - val_num]

    # split dataset
    train_pos, val_pos, test_pos = random_split(pos_data, split_size, generator=manual_seed)
    train_neg, val_neg, test_neg = random_split(neg_data, split_size, generator=manual_seed)

    # data loader
    stack_dataset = [train_pos, val_pos, test_pos, train_neg, val_neg, test_neg]
    stack_loaders = list()
    for dataset in stack_dataset:
        data_loader = DataLoader(dataset, batch_size=batch_size, shuffle=True, num_workers=num_cpu)
        stack_loaders.append(data_loader)

    return stack_loaders

# %% [markdown]
# **Exercise** Check if your datasets have the same lenght to avoid the bias by over representation of one class.

# %%
# # Exercise
# load data 
stack_promotors = load_data_new(path_promotors, path_random_nopromotors, train_potion=0.8, batch_size=32, num_cpu=0, device=device)
print('Training promotor dataset length:', len(stack_promotors[0].dataset))
print('Training random dataset length:', len(stack_promotors[3].dataset))
# the size is equall, there should not be bias by overrepresentation in the model
# Out:
# Key error :  N 200
# Training promotor dataset length: 23079
# Training random dataset length: 23079

# %%
# Check the number of non-promotor sequences in the dataset 
non_prom = 0
for i in stack_promotors[0].dataset:
    if i[1] == 0:
        non_prom += 1
print(f'In the promotor dataset there are {non_prom} non-promotor sequences')

non_prom = 0
for i in stack_promotors[3].dataset:
    if i[1] == 0:
        non_prom += 1
print(f'In the random dataset there are {non_prom} non-promotor sequences')
# works fine now
# Out:
# In the promotor dataset there are 0 non-promotor sequences
# In the random dataset there are 23079 non-promotor sequences

# %% [markdown]
# **Exercise** Train the model that takes promoters as positive examples and random sequences as negative.

# %%
def train_new(data_path_promotors,data_path_random, pretrain=None, exp_name="test", training=True, ker=None, epoch_num=1000):
    """
    Training
    :param data_path: Path to the txt data file
    :param pretrain: Path to weight for continue training
    :param exp_name: Folder name to save the results
    :param training: If False, performs testing only
    :param ker: List kernel size of list CNN applying to the protein sequence
    :param epoch_num: Max epoch to train
    """
    if ker is None:
        ker = [27, 14, 7]

    # create the experiment folder to save the result
    output = Path("./output")
    output.mkdir(exist_ok=True)
    exp_folder = output.joinpath(exp_name)
    exp_folder.mkdir(exist_ok=True)

    # load data
    ic("Data loading")
    data = load_data_new(data_path_promotors,data_path_random,device=device)
    train_pos, val_pos, test_pos, train_neg, val_neg, test_neg = data

    # model define
    net = DeePromoter(ker)
    net.to(device)

    # load pre-train model
    if pretrain is not None:
        net.load_state_dict(torch.load(pretrain))

    # define loss, optimizer
    criterion = nn.CrossEntropyLoss()
    optimizer = optim.Adam(net.parameters(), lr=0.00001)
    mcc_scores, precision_scores, recall_scores = [], [], []
    running_loss = 0
    best_mcc = 0
    best_precision = 0
    best_recall = 0
    break_after = 10
    last_update_best = 0
    pbar = range(epoch_num)
    ic("Start training")
    if training:
        for epoch in pbar:
            for i, (batch_pos, batch_neg) in enumerate(zip(train_pos, train_neg)):
                inputs = torch.cat((batch_pos[0], batch_neg[0]), dim=0)
                labels = torch.cat((batch_pos[1], batch_neg[1]), dim=0)

                # zero the parameter gradients
                optimizer.zero_grad()

                # pass model to
                outputs = net(inputs)
                loss = criterion(outputs, labels.long())
                loss.backward()
                optimizer.step()

                running_loss += loss.item()


            if epoch % 10 == 0:
                torch.save(net.state_dict(), str(exp_folder.joinpath("epoch_" + str(epoch) + ".pth")))
                net.eval()
                eval_data, _ , _= evaluate(net, [val_pos, val_neg])
                precision, recall, MCC = mcc(eval_data)
                mcc_scores.append(MCC)
                precision_scores.append(precision)
                recall_scores.append(recall)
                net.train()
                ic("Epoch :", epoch, "Experiment :", exp_name)
                ic("precision :", precision)
                ic("recall :", recall)
                ic("MCC :", MCC)

                # save best model
                if precision > best_precision:
                    best_precision = precision
                    ic("Update best precision")
                    torch.save(net.state_dict(), str(exp_folder.joinpath("best_precision.pth")))
                if recall > best_recall:
                    best_recall = recall
                    ic("Update best recall")
                    torch.save(net.state_dict(), str(exp_folder.joinpath("best_recall.pth")))
                if MCC > best_mcc:
                    ic("Update best MCC")
                    best_mcc = MCC
                    torch.save(net.state_dict(), str(exp_folder.joinpath("best_mcc.pth")))
                    last_update_best = 0
                else:
                    last_update_best += 1
                if last_update_best >= break_after:
                    break
            if last_update_best >= break_after:
                break

    return mcc_scores, precision_scores, recall_scores

# %%
#Later we load the provided trained model - run this cell if you want to train your own one
#mcc_scores, precision_scores, recall_scores = train_new(path_promotors,path_random_nopromotors  ,pretrain=None, exp_name="train_promoters_random", training=True, ker=None, epoch_num=400)

# I would not run this cell. As it takes a lot of time to train the model on my computer. (I have no GPU)
# Out:
# ic| 'Data loading'
# Key error :  N 200
# ic| 'Start training'
# ic| "Epoch :": 'Epoch :'
#     epoch: 0
#     "Experiment :": 'Experiment :'
#     exp_name: 'train_promoters_random'
# ic| 'precision :', precision: 0.7885345482156416
# ic| 'recall :', recall: 0.7201803051317615
# ic| 'MCC :', MCC: 0.5290371944270882
# ic| 'Update best precision'
# ic| 'Update best recall'
# ic| 'Update best MCC'
# ic| "Epoch :": 'Epoch :'
#     epoch: 10
#     "Experiment :": 'Experiment :'
#     exp_name: 'train_promoters_random'
# ic| 'precision :', precision: 0.8385437277404036
# ic| 'recall :', recall: 0.734743411927878
# ic| 'MCC :', MCC: 0.5978715297098016
# ic| 'Update best precision'
# ic| 'Update best recall'
# ic| 'Update best MCC'
# ic| "Epoch :": 'Epoch :'
#     epoch: 20
#     "Experiment :": 'Experiment :'
#     exp_name: 'train_promoters_random'
# ic| 'precision :', precision: 0.8474508229626656
# ic| 'recall :', recall: 0.7319694868238558
# ic| 'MCC :', MCC: 0.6058595855317958
# ic| 'Update best precision'
# ic| 'Update best MCC'
# ic| "Epoch :": 'Epoch :'
#     epoch: 30
#     "Experiment :": 'Experiment :'
#     exp_name: 'train_promoters_random'
# ic| 'precision :', precision: 0.8668331252600916
# ic| 'recall :', recall: 0.7222607489597781
# ic| 'MCC :', MCC: 0.6199874416757858
# ic| 'Update best precision'
# ic| 'Update best MCC'
# ic| "Epoch :": 'Epoch :'
#     epoch: 40
#     "Experiment :": 'Experiment :'
#     exp_name: 'train_promoters_random'
# ic| 'precision :', precision: 0.8532544378698225
# ic| 'recall :', recall: 0.75
# ic| 'MCC :', MCC: 0.6256101003537397
# ic| 'Update best recall'
# ic| 'Update best MCC'
# ic| "Epoch :": 'Epoch :'
#     epoch: 50
#     "Experiment :": 'Experiment :'
#     exp_name: 'train_promoters_random'
# ic| 'precision :', precision: 0.8694770976895014
# ic| 'recall :', recall: 0.7437586685159501
# ic| 'MCC :', MCC: 0.6388212168989309
# ic| 'Update best precision'
# ic| 'Update best MCC'
# ic| "Epoch :": 'Epoch :'
#     epoch: 60
#     "Experiment :": 'Experiment :'
#     exp_name: 'train_promoters_random'
# ic| 'precision :', precision: 0.8779093507554103
# ic| 'recall :', recall: 0.7454923717059639
# ic| 'MCC :', MCC: 0.6492446805066433
# ic| 'Update best precision'
# ic| 'Update best MCC'
# ic| "Epoch :": 'Epoch :'
#     epoch: 70
#     "Experiment :": 'Experiment :'
#     exp_name: 'train_promoters_random'
# ic| 'precision :', precision: 0.8886572143452878
# ic| 'recall :', recall: 0.7389042995839112
# ic| 'MCC :', MCC: 0.6557017884183968
# ic| 'Update best precision'
# ic| 'Update best MCC'
# ic| "Epoch :": 'Epoch :'
#     epoch: 80
#     "Experiment :": 'Experiment :'
#     exp_name: 'train_promoters_random'
# ic| 'precision :', precision: 0.8907216494845361
# ic| 'recall :', recall: 0.7489597780859917
# ic| 'MCC :', MCC: 0.665556845290026
# ic| 'Update best precision'
# ic| 'Update best MCC'
# ic| "Epoch :": 'Epoch :'
#     epoch: 90
#     "Experiment :": 'Experiment :'
#     exp_name: 'train_promoters_random'
# ic| 'precision :', precision: 0.885954381752701
# ic| 'recall :', recall: 0.7676837725381415
# ic| 'MCC :', MCC: 0.6749034361668851
# ic| 'Update best recall'
# ic| 'Update best MCC'
# ic| "Epoch :": 'Epoch :'
#     epoch: 100
#     "Experiment :": 'Experiment :'
#     exp_name: 'train_promoters_random'
# ic| 'precision :', precision: 0.8865529551765172
# ic| 'recall :', recall: 0.7749653259361997
# ic| 'MCC :', MCC: 0.6812151092215596
# ic| 'Update best recall'
# ic| 'Update best MCC'
# ic| "Epoch :": 'Epoch :'
#     epoch: 110
#     "Experiment :": 'Experiment :'
#     exp_name: 'train_promoters_random'
# ic| 'precision :', precision: 0.8897731794667728
# ic| 'recall :', recall: 0.7753120665742025
# ic| 'MCC :', MCC: 0.684956033022434
# ic| 'Update best recall'
# ic| 'Update best MCC'
# ic| "Epoch :": 'Epoch :'
#     epoch: 120
#     "Experiment :": 'Experiment :'
#     exp_name: 'train_promoters_random'
# ic| 'precision :', precision: 0.8925718849840255
# ic| 'recall :', recall: 0.7749653259361997
# ic| 'MCC :', MCC: 0.6876877309991692
# ic| 'Update best precision'
# ic| 'Update best MCC'
# ic| "Epoch :": 'Epoch :'
#     epoch: 130
#     "Experiment :": 'Experiment :'
#     exp_name: 'train_promoters_random'
# ic| 'precision :', precision: 0.9016326530612245
# ic| 'recall :', recall: 0.7659500693481276
# ic| 'MCC :', MCC: 0.6902459404028465
# ic| 'Update best precision'
# ic| 'Update best MCC'
# ic| "Epoch :": 'Epoch :'
#     epoch: 140
#     "Experiment :": 'Experiment :'
#     exp_name: 'train_promoters_random'
# ic| 'precision :', precision: 0.9035159443990188
# ic| 'recall :', recall: 0.7662968099861304
# ic| 'MCC :', MCC: 0.6924989319607684
# ic| 'Update best precision'
# ic| 'Update best MCC'
# ic| "Epoch :": 'Epoch :'
#     epoch: 150
#     "Experiment :": 'Experiment :'
#     exp_name: 'train_promoters_random'
# ic| 'precision :', precision: 0.9075456053067993
# ic| 'recall :', recall: 0.7590152565880721
# ic| 'MCC :', MCC: 0.6910092893167433
# ic| 'Update best precision'
# ic| "Epoch :": 'Epoch :'
#     epoch: 160
#     "Experiment :": 'Experiment :'
#     exp_name: 'train_promoters_random'
# ic| 'precision :', precision: 0.9012545528126265
# ic| 'recall :', recall: 0.7721914008321775
# ic| 'MCC :', MCC: 0.6947473004493163
# ic| 'Update best MCC'
# ic| "Epoch :": 'Epoch :'
#     epoch: 170
#     "Experiment :": 'Experiment :'
#     exp_name: 'train_promoters_random'
# ic| 'precision :', precision: 0.9091286307053942
# ic| 'recall :', recall: 0.7597087378640777
# ic| 'MCC :', MCC: 0.6931991849651538
# ic| 'Update best precision'
# ic| "Epoch :": 'Epoch :'
#     epoch: 180
#     "Experiment :": 'Experiment :'
#     exp_name: 'train_promoters_random'
# ic| 'precision :', precision: 0.9063777596075225
# ic| 'recall :', recall: 0.7687239944521498
# ic| 'MCC :', MCC: 0.6974102719037526
# ic| 'Update best MCC'
# ic| "Epoch :": 'Epoch :'
#     epoch: 190
#     "Experiment :": 'Experiment :'
#     exp_name: 'train_promoters_random'
# ic| 'precision :', precision: 0.9030694668820679
# ic| 'recall :', recall: 0.7753120665742025
# ic| 'MCC :', MCC: 0.6991257584888637
# ic| 'Update best MCC'
# ic| "Epoch :": 'Epoch :'
#     epoch: 200
#     "Experiment :": 'Experiment :'
#     exp_name: 'train_promoters_random'
# ic| 'precision :', precision: 0.900040144520273
# ic| 'recall :', recall: 0.7773925104022191
# ic| 'MCC :', MCC: 0.697561036374852
# ic| 'Update best recall'
# ic| "Epoch :": 'Epoch :'
#     epoch: 210
#     "Experiment :": 'Experiment :'
#     exp_name: 'train_promoters_random'
# ic| 'precision :', precision: 0.9013632718524459
# ic| 'recall :', recall: 0.7794729542302358
# ic| 'MCC :', MCC: 0.7006102890930276
# ic| 'Update best recall'
# ic| 'Update best MCC'
# ic| "Epoch :": 'Epoch :'
#     epoch: 220
#     "Experiment :": 'Experiment :'
#     exp_name: 'train_promoters_random'
# ic| 'precision :', precision: 0.9053398058252428
# ic| 'recall :', recall: 0.776005547850208
# ic| 'MCC :', MCC: 0.7020691380194236
# ic| 'Update best MCC'
# ic| "Epoch :": 'Epoch :'
#     epoch: 230
#     "Experiment :": 'Experiment :'
#     exp_name: 'train_promoters_random'
# ic| 'precision :', precision: 0.9043969342476805
# ic| 'recall :', recall: 0.7773925104022191
# ic| 'MCC :', MCC: 0.7021730822943103
# ic| 'Update best MCC'
# ic| "Epoch :": 'Epoch :'
#     epoch: 240
#     "Experiment :": 'Experiment :'
#     exp_name: 'train_promoters_random'
# ic| 'precision :', precision: 0.8872380952380953
# ic| 'recall :', recall: 0.8075589459084604
# ic| 'MCC :', MCC: 0.7077836633063107
# ic| 'Update best recall'
# ic| 'Update best MCC'
# ic| "Epoch :": 'Epoch :'
#     epoch: 250
#     "Experiment :": 'Experiment :'
#     exp_name: 'train_promoters_random'
# ic| 'precision :', precision: 0.9090909090909091
# ic| 'recall :', recall: 0.7766990291262136
# ic| 'MCC :', MCC: 0.7065618047809736
# ic| "Epoch :": 'Epoch :'
#     epoch: 260
#     "Experiment :": 'Experiment :'
#     exp_name: 'train_promoters_random'
# ic| 'precision :', precision: 0.9060509554140127
# ic| 'recall :', recall: 0.7891816920943134
# ic| 'MCC :', MCC: 0.7133097360273561
# ic| 'Update best MCC'
# ic| "Epoch :": 'Epoch :'
#     epoch: 270
#     "Experiment :": 'Experiment :'
#     exp_name: 'train_promoters_random'
# ic| 'precision :', precision: 0.9057798891528107
# ic| 'recall :', recall: 0.7933425797503467
# ic| 'MCC :', MCC: 0.7163589359289757
# ic| 'Update best MCC'
# ic| "Epoch :": 'Epoch :'
#     epoch: 280
#     "Experiment :": 'Experiment :'
#     exp_name: 'train_promoters_random'
# ic| 'precision :', precision: 0.9011764705882352
# ic| 'recall :', recall: 0.7968099861303745
# ic| 'MCC :', MCC: 0.7142372875562383
# ic| "Epoch :": 'Epoch :'
#     epoch: 290
#     "Experiment :": 'Experiment :'
#     exp_name: 'train_promoters_random'
# ic| 'precision :', precision: 0.8996901626646011
# ic| 'recall :', recall: 0.8054785020804438
# ic| 'MCC :', MCC: 0.7196290526870578
# ic| 'Update best MCC'
# ic| "Epoch :": 'Epoch :'
#     epoch: 300
#     "Experiment :": 'Experiment :'
#     exp_name: 'train_promoters_random'
# ic| 'precision :', precision: 0.8975834292289988
# ic| 'recall :', recall: 0.811373092926491
# ic| 'MCC :', MCC: 0.722131913832549
# ic| 'Update best recall'
# ic| 'Update best MCC'
# ic| "Epoch :": 'Epoch :'
#     epoch: 310
#     "Experiment :": 'Experiment :'
#     exp_name: 'train_promoters_random'
# ic| 'precision :', precision: 0.9066561638440331
# ic| 'recall :', recall: 0.7981969486823856
# ic| 'MCC :', MCC: 0.7211982812502025
# ic| "Epoch :": 'Epoch :'
#     epoch: 320
#     "Experiment :": 'Experiment :'
#     exp_name: 'train_promoters_random'
# ic| 'precision :', precision: 0.9148163100524829
# ic| 'recall :', recall: 0.7857142857142857
# ic| 'MCC :', MCC: 0.7197553169596004
# ic| 'Update best precision'
# ic| "Epoch :": 'Epoch :'
#     epoch: 330
#     "Experiment :": 'Experiment :'
#     exp_name: 'train_promoters_random'
# ic| 'precision :', precision: 0.9091266719118805
# ic| 'recall :', recall: 0.8013176144244105
# ic| 'MCC :', MCC: 0.7263457175556804
# ic| 'Update best MCC'
# ic| "Epoch :": 'Epoch :'
#     epoch: 340
#     "Experiment :": 'Experiment :'
#     exp_name: 'train_promoters_random'
# ic| 'precision :', precision: 0.920641447368421
# ic| 'recall :', recall: 0.7763522884882108
# ic| 'MCC :', MCC: 0.7183081980984968
# ic| 'Update best precision'
# ic| "Epoch :": 'Epoch :'
#     epoch: 350
#     "Experiment :": 'Experiment :'
#     exp_name: 'train_promoters_random'
# ic| 'precision :', precision: 0.9231087226126499
# ic| 'recall :', recall: 0.7742718446601942
# ic| 'MCC :', MCC: 0.71918783827541
# ic| 'Update best precision'
# ic| "Epoch :": 'Epoch :'
#     epoch: 360
#     "Experiment :": 'Experiment :'
#     exp_name: 'train_promoters_random'
# ic| 'precision :', precision: 0.903512157468159
# ic| 'recall :', recall: 0.8117198335644937
# ic| 'MCC :', MCC: 0.7288056300376097
# ic| 'Update best recall'
# ic| 'Update best MCC'
# ic| "Epoch :": 'Epoch :'
#     epoch: 370
#     "Experiment :": 'Experiment :'
#     exp_name: 'train_promoters_random'
# ic| 'precision :', precision: 0.908524717789023
# ic| 'recall :', recall: 0.8092926490984743
# ic| 'MCC :', MCC: 0.7321891119645076
# ic| 'Update best MCC'
# ic| "Epoch :": 'Epoch :'
#     epoch: 380
#     "Experiment :": 'Experiment :'
#     exp_name: 'train_promoters_random'
# ic| 'precision :', precision: 0.9211165048543689
# ic| 'recall :', recall: 0.7895284327323162
# ic| 'MCC :', MCC: 0.7293951823135928
# ic| "Epoch :": 'Epoch :'
#     epoch: 390
#     "Experiment :": 'Experiment :'
#     exp_name: 'train_promoters_random'
# ic| 'precision :', precision: 0.9181380417335474
# ic| 'recall :', recall: 0.7933425797503467
# ic| 'MCC :', MCC: 0.729376470694577

# %%
plt.plot(mcc_scores, label='mcc')
plt.plot(precision_scores, label='precision')
plt.plot(recall_scores, label='recall')
plt.title('promotors dataset vs random genomic sequences')
plt.xlabel('checkpoint')
plt.ylabel('scores')
plt.legend()
plt.show()

# %%
def test_new(data_path_promotors,data_path_human_random ,pretrain, ker=None):
    if ker is None:
        ker = [27, 14, 7]

    dataloader = load_data_new(data_path_promotors,data_path_human_random ,device=device)
    # Assuming `positive_dataloader` and `negative_dataloader` are already defined in the repository files
    positive_dataloader = dataloader[2]  # Your DataLoader for positive examples
    negative_dataloader = dataloader[5]  # Your DataLoader for negative examples

    # Extract datasets from each DataLoader
    positive_dataset = positive_dataloader.dataset
    negative_dataset = negative_dataloader.dataset

    # Combine the datasets
    combined_dataset = ConcatDataset([positive_dataset, negative_dataset])

    # Create a new DataLoader from the combined dataset
    combined_dataloader = DataLoader(combined_dataset, batch_size=32, shuffle=True)

    # model define
    net = DeePromoter(ker)
    net.to(device)

    net.load_state_dict(torch.load(pretrain,map_location=torch.device(device)))

    net.eval()
    eval_data, results, confusion_matrice = evaluate(net, [combined_dataloader])

    return eval_data, results, confusion_matrice

# %%
#Load pretrained model
path_promotors_random_model = 'C:/Users/nelia/OneDrive/Рабочий стол/semester 2/DeepLife/03/deep4life_files/data/models/model_random_promotors.pth'

# %% [markdown]
# **Excercise** Plot confusion matrix and compute accuracy for the new model. What do you think about the results?

# %%
## Excercise
# calculate metrics 
eval_data, results, confusion_matrice = test_new(path_promotors,path_random_nopromotors, pretrain=path_promotors_random_model)

# plot confusion matrix
plot_confusion_matrix(confusion_matrice)

# calculate accuracy
all = np.sum(confusion_matrice)
correct =np.sum( confusion_matrice[0,0] + confusion_matrice[1,1])
print(f'The accuracy of the DeePromoter based on the promotor dataset vs random genomic sequences is {round(correct/all,2)*100}%')
# worse performance of the model, when using random genomic sequences as negative dataset.
# Out:
# Key error :  N 200
# The accuracy of the DeePromoter based on the promotor dataset vs random genomic sequences is 87.0%

# %% [markdown]
# ### Summary
# The results demonstrated that Deepromoter is a model with strong performance metrics. However, a deeper analysis of the problem and the data suggests that the tool isn't fulfilling its intended purpose. While Deepromoter excels at distinguishing sequence randomization, it falls short when it comes to discerning promoter regions from random genomic regions.

# %% [markdown]
# **Additional task** Let's examine the datasets to identify some characteristics. Plot the distribution of nucleotides in both the promoter and random sequence datasets. Can you observe any noticeable differences?

# %%
# Additional task
import seaborn as sns
# Count nucleotides 
def count_nucleotides(file):
    As = []
    Ts = []
    Gs = []
    Cs = []
    with open(file, 'r') as f:
        for line in f:
            line = line.upper()
            As.append(line.count('A')/len(line)*100)
            Ts.append(line.count('T')/len(line)*100)
            Gs.append(line.count('G')/len(line)*100)
            Cs.append(line.count('C')/len(line)*100)

    return As, Ts, Gs, Cs

random_As, random_Ts, random_Gs, random_Cs = count_nucleotides(path_random_nopromotors)
promoter_As, promoter_Ts, promoter_Gs, promoter_Cs = count_nucleotides(path_promotors)

# %%
# Plot the histogram and density plot
fig, axes = plt.subplots(2,2, figsize=(15,15))
sns.histplot(random_As, bins=10, kde=True, color="blue", stat="density", ax=axes[0,0])
sns.histplot(promoter_As, bins=10, kde=True, color="red", stat="density", ax = axes[0,0])
axes[0,0].legend(['Random', 'Promoter'])
axes[0,0].set_title('Distribution of A nucleotides')

sns.histplot(random_Ts, bins=10, kde=True, color="blue", stat="density", ax = axes[0,1])
sns.histplot(promoter_Ts, bins=10, kde=True, color="red", stat="density", ax = axes[0,1])
axes[0,1].legend(['Random', 'Promoter'])
axes[0,1].set_title('Distribution of T nucleotides')

sns.histplot(random_Gs, bins=10, kde=True, color="blue", stat="density", ax = axes[1,0])
sns.histplot(promoter_Gs, bins=10, kde=True, color="red", stat="density", ax = axes[1,0])
axes[1,0].legend(['Random', 'Promoter'])
axes[1,0].set_title('Distribution of G nucleotides')

sns.histplot(random_Cs, bins=10, kde=True, color="blue", stat="density", ax = axes[1,1])
sns.histplot(promoter_Cs, bins=10, kde=True, color="red", stat="density", ax = axes[1,1])
axes[1,1].legend(['Random', 'Promoter'])
axes[1,1].set_title('Distribution of C nucleotides')

plt.show()


# Excercise: Can you observe any noticeable differences?
# Promoter region is more rich in G and C nucleotides than random genomic sequences. Furthermore, distribution of A and T nucleotides is wider in promoter regions. 
# There is less G and C in random genomic sequences, and it is less variable, distibution is more narrow.
